# %%
import pandas as pd #biblioteca pandas - analise de dados
import matplotlib.pyplot as plt #biblioteca de graficos
from statsmodels.tsa.seasonal import seasonal_decompose #Time Series Analysis

eel = pd.read_csv('est_est_log_2019-05-13.csv').set_index('id') #como faço para alterar essa data? - Atualizar
num_sex = eel.query("util == 'nasc'").query("num_nasc < 200")
datas = ['date_hoje', 'date_nasc', 'data_inicio', 'date_acas', 'date_nasc_acas', 'date_sex', 'data_solic', 'data_forn', 'data_fim']
for c in datas:
    num_sex[c] = pd.to_datetime(num_sex[c], unit = 's') #indica o formato das datas

# %%
num_sex.head() #chama as 5 primeiras linhas (instâncias)
# Out:
#               date_hoje   user     ling  num_ani  m_f           date_nasc  \
# id
# 116 2014-09-23 17:40:33  Tania  Swiss E        5  AAA 1970-01-01 00:11:06
# 117 2014-09-23 17:40:33  Tania  Swiss E       10  AAA 1970-01-01 00:11:06
# 118 2014-09-23 17:40:33  Tania  Swiss C       20  AAA 1970-01-01 00:11:06
# 119 2014-09-23 17:40:47  Tania  Swiss E       10  AAA 1970-01-01 00:11:06
# 120 2014-09-23 17:40:47  Tania  Swiss E       20  AAA 1970-01-01 00:11:06
#
#     id_orig  util  id_solic         data_inicio     ...      \
# id                                                  ...
# 116      54  nasc       666 1970-01-01 00:11:06     ...
# 117      56  nasc       666 1970-01-01 00:11:06     ...
# 118      62  nasc       666 1970-01-01 00:11:06     ...
# 119     116  nasc       666 1970-01-01 00:11:06     ...
# 120     117  nasc       666 1970-01-01 00:11:06     ...
#
#               date_acas      date_nasc_acas  num_nasc            date_sex  \
# id
# 116 2014-08-26 17:06:07 2014-09-23 17:40:33         5 2014-10-14 17:40:33
# 117 2014-08-26 17:14:19 2014-09-23 17:40:33        10 2014-10-14 17:40:33
# 118 2014-08-26 17:46:07 2014-09-23 17:40:33        20 2014-10-14 17:40:33
# 119 2014-08-26 17:06:07 2014-09-23 17:40:47        10 2014-10-14 17:40:47
# 120 2014-08-26 17:14:19 2014-09-23 17:40:47        20 2014-10-14 17:40:47
#
#     num_sex_m num_sex_f  num_ani_ini  num_ani_fim obs_desc grupos_acas
# id
# 116       666       666          666          666      AAA         AAA
# 117       666       666          666          666      AAA         AAA
# 118       666       666          666          666      AAA         AAA
# 119       666       666          666          666      AAA         AAA
# 120       666       666          666          666      AAA         AAA
#
# [5 rows x 28 columns]

# %%
len(num_sex) #tamanho - numero de entradas
# Out:
# 1795

# %%
num_sex['num_nasc'].sum() #soma do numero de nascidos
# Out:
# 15022

# %%
inic = num_sex.loc[num_sex.index.min(), "date_hoje"] #loc: localizador - localizando a primeira data
fim = num_sex.loc[num_sex.index.max(), "date_hoje"] #localizando a ultima data
num_sex.plot(
        kind='area',
        x='date_hoje',
        y='num_nasc',
        figsize=(25, 5),
        colormap='Greens_r',
        title=f'Número de Animais Nascidos {inic.day}/{inic.month}/{inic.year} até {fim.day}/{fim.month}/{fim.year}'
)
plt.legend(['Número de animais'])
plt.xlabel('Data Nascimento')
plt.ylabel('Quantidade Nascidos')
# Out:
# Text(0, 0.5, 'Quantidade Nascidos')

# %%
#numero de nascidos por linhagem
num_sex.query("ling == 'Swiss E'").plot( #ver erro 
        kind='area', #tipo de grafico
        x='date_hoje',
        y='num_nasc',
        figsize=(25, 5),
        colormap='RdBu',
        title=f'Número de Animais Nascidos {inic.day}/{inic.month}/{inic.year} até {fim.day}/{fim.month}/{fim.year}'
)
plt.legend(['Número de animais'])
plt.xlabel('Data Nascimento')
plt.ylabel('Quantidade Nascidos')
# Out:
# Text(0, 0.5, 'Quantidade Nascidos')

# %%
num_sex.loc[num_sex.index.min(), 'date_hoje'] #localizar a primeira data
# Out:
# Timestamp('2014-09-23 17:40:33')

# %%
num_sex.loc[num_sex.index.max(), 'date_hoje'] #localizar a ultima data
# Out:
# Timestamp('2019-06-13 14:42:22')

# %%
#número de animais que nascem em média no biotério
#1) pergunta: nascidos no total de 5 anos.
temp_num_sex = pd.DataFrame(num_sex['date_hoje'])
temp_num_sex['num_nasc'] = num_sex['num_nasc']
temp_num_sex = temp_num_sex.set_index('date_hoje')
#num_sex.query("ling == 'Balb/c'").plot(

#nao sei esse coco
#linhagem = pd.DataFrame(num_sex['data_hoje'])
#linhagem['ling'] = num_sex['num_nasc']
#linhagem = ling.set_index('date_hoje')


tsAno = temp_num_sex.resample('A').sum() #resample('A') agrupamento por ano, sum() somando os dados
#tsAno = num_sex.query("ling == 'Balb/c'").plot(
#tsAno.query("ling == 'Balb/c'").plot(
tsAno.plot(
    figsize=(10, 5),
        colormap='RdBu',
        title=f'Número de Animais Nascidos {inic.day}/{inic.month}/{inic.year} até {fim.day}/{fim.month}/{fim.year}'
)
plt.legend(['Número de animais'])
plt.xlabel('Ano Nascimento')
plt.ylabel('Soma de animais')
# Out:
# Text(0, 0.5, 'Soma de animais')

# %%
#Dia do acasalamneto até o nascimento dentro das linhagens
acas = pd.DataFrame(num_sex['date_nasc_acas'])
date_nasc_acas.query("ling == 'Swiss E'").plot( #ver erro 
        kind='area', #tipo de grafico
        x='date_hoje',
        y='num_nasc',
        figsize=(25, 5),
        colormap='RdBu',
        title=f'Número de Animais Nascidos {inic.day}/{inic.month}/{inic.year} até {fim.day}/{fim.month}/{fim.year}'
)
plt.legend(['Número de animais'])
plt.xlabel('Data Nascimento')
plt.ylabel('Quantidade Nascidos')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-93754e879c0c> in <module>
#       1 #Dia do acasalamneot até o nascimento dentro das linhagens
#       2 acas = pd.DataFrame(num_sex['date_nasc_acas'])
# ----> 3 date_nasc_acas.query("ling == 'Swiss E'").plot( #ver erro
#       4         kind='area', #tipo de grafico
#       5         x='date_hoje',
#
# NameError: name 'date_nasc_acas' is not defined

# %%
#2) pergunta: nascidos mês a mês
tsMes = temp_num_sex.groupby([lambda x: x.month]).sum() # agrupamento por mes
tsMes.plot(
        figsize=(10, 5),
        colormap='RdBu',
        title=f'Número de Animais Nascidos {inic.day}/{inic.month}/{inic.year} até {fim.day}/{fim.month}/{fim.year}'
)
plt.legend(['Número de animais']) #legenda
plt.xlabel('Mês Nascimento') #identificação eixo x
plt.ylabel('Soma Nascidos') #identificação eixo y
# Out:
# Text(0, 0.5, 'Soma Nascidos')

# %%
temp_num_sex.plot(
        figsize=(25, 5),
        colormap='RdBu',
        title=f'Número de Animais Nascidos {inic.day}/{inic.month}/{inic.year} até {fim.day}/{fim.month}/{fim.year}'
)

# %%
ts = temp_num_sex['num_nasc']
dec = seasonal_decompose(ts, freq=12)
dec.trend.plot(
        figsize=(25, 5),
        colormap='RdBu',
        title=f'Número de Animais Nascidos {inic.day}/{inic.month}/{inic.year} até {fim.day}/{fim.month}/{fim.year}'
)

# %%
dec.seasonal.plot(
        figsize=(25, 5),
        colormap='RdBu',
        title=f'Número de Animais Nascidos {inic.day}/{inic.month}/{inic.year} até {fim.day}/{fim.month}/{fim.year}'
)

# %%
dec.resid.plot(
        figsize=(25, 5),
        colormap='RdBu',
        title=f'Número de Animais Nascidos {inic.day}/{inic.month}/{inic.year} até {fim.day}/{fim.month}/{fim.year}'
)

# %%
plt.figure(figsize=(25, 15))
plt.legend(['Decomposição da Série Temporal Nascimento de Animais'])
plt.subplot(4, 1, 1)
plt.plot(ts, label = 'Nº nascidos', color='red')
plt.legend(loc = 'best')

plt.subplot(4, 1, 2)
plt.plot(dec.trend, label = 'Tendência', color='green')
plt.legend(loc = 'best')

plt.subplot(4, 1, 3)
plt.plot(dec.seasonal, label = 'Sazonalidade', color='blue')
plt.legend(loc = 'best')

plt.subplot(4, 1, 4)
plt.plot(dec.resid, label = 'Aleatoriedade', color='grey')
plt.legend(loc = 'best')

plt.xlabel('Data Nascimento')
plt.tight_layout()

# %%
'''
# Transforma time() em data
import time
timestamp = num_sex.loc[num_sex.index[len(num_sex)-1:], 'date_hoje']
fim = time.strftime("%Y-%m-%d", time.localtime(timestamp))
fim

# Cria nova DataFrame com duas colunas e index
temp_num_sex = pd.DataFrame(num_sex['date_hoje'])
temp_num_sex['num_nasc'] = num_sex['num_nasc']
temp_num_sex = temp_num_sex.set_index('date_hoje')
temp_num_sex.plot(figsize=(25, 5))
'''
# Out:
# '\n# Transforma time() em data\nimport time\ntimestamp = num_sex.loc[num_sex.index[len(num_sex)-1:], \'date_hoje\']\nfim = time.strftime("%Y-%m-%d", time.localtime(timestamp))\nfim\n\n# Cria nova DataFrame com duas colunas e index\ntemp_num_sex = pd.DataFrame(num_sex[\'date_hoje\'])\ntemp_num_sex[\'num_nasc\'] = num_sex[\'num_nasc\']\ntemp_num_sex = temp_num_sex.set_index(\'date_hoje\')\ntemp_num_sex.plot(figsize=(25, 5))\n'
