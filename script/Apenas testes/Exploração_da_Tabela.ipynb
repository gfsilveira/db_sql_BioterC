# %%
import pandas as pd
est_est_log = pd.read_csv('est_est_log_2019-03-07.csv').set_index('id')
est_est_log.head(10)
# Out:
#      date_hoje      user     ling  num_ani m_f   date_nasc id_orig   util  \
# id
# 1   1408122540  Giovanny  Swiss A        3   m  1402372800   inser  inser
# 2   1408122540  Giovanny  Swiss A        2   f  1402372800   inser  inser
# 3   1408122540  Giovanny  Swiss B        3   m  1402372800   inser  inser
# 4   1408122540  Giovanny  Swiss B        3   f  1402372800   inser  inser
# 5   1408122540  Giovanny  Swiss B        4   f  1402372800   inser  inser
# 6   1408122540  Giovanny  Swiss B        3   f  1396497600   inser  inser
# 7   1408122540  Giovanny  Swiss C        2   f  1396324800   inser  inser
# 8   1408122801  Giovanny  Swiss C        5   f  1404792000   inser  inser
# 9   1408122801  Giovanny  Swiss C        3   m  1404792000   inser  inser
# 10  1408122801  Giovanny  Swiss D        3   f  1404705600   inser  inser
#
#     id_solic  data_inicio     ...      date_acas  date_nasc_acas  num_nasc  \
# id                            ...
# ...
