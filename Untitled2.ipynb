# %%
import matplotlib.pyplot

# %%
matplotlib.__version__
# Out:
# '3.3.0'

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3])

csfont = {'fontname':'Comic Sans MS',
         'size':15}
plt.title('Testando essa merda de fonte', **csfont)
plt.ylabel('Frequência Absoluta Simples', **csfont)
plt.show()

# %%
import sys
# !{sys.executable} -m pip install textblob
# Out:
# ...
#     100% |████████████████████████████████| 645kB 3.1MB/s
# ...

# %%
from textblob import TextBlob
lista = ['Descarte Zootécnico', 'Fim de Experimento',
 'Fim Experimento',
 'Encontrado Morto',
 'Velhos',
 'Erro de cadastro',
 'Canibalismo',
 'Fornecido Zoológico',
 'Para acasalamento',
 'UEL',
 'Animais Doentes',
 'Mudança',
 'Transferencia cx',
 'Cascavel',
 'Troca de Macho',
 'Monitoramento Sanitário',
 'Ivermectina',
 'Excesso de Filhotes',
 'Exp Lorena']

for x in lista:
    test = TextBlob(x)
    ingles = test.translate(from_lang='pt',to='en')
    print(ingles)
# Out:
# Zootechnical Disposal
# End of Experiment
# End Experiment
# Found Dead
# Old
# Registration error
# Cannibalism
# Provided Zoo
# For mating
# ---------------------------------------------------------------------------
# NotTranslated                             Traceback (most recent call last)
# <ipython-input-49-38275e9e3088> in <module>
#      21 for x in lista:
#      22     test = TextBlob(x)
# ---> 23     ingles = test.translate(from_lang='pt',to='en')
#      24     print(ingles)
#
# ~/anaconda3/lib/python3.7/site-packages/textblob/blob.py in translate(self, from_lang, to)
#     545         """
#     546         return self.__class__(self.translator.translate(self.raw,
# --> 547                               from_lang=from_lang, to_lang=to))
#     548
#     549     def detect_language(self):
#
# ~/anaconda3/lib/python3.7/site-packages/textblob/translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      59             except IndexError:
# ...

# %%
lista = ['Descarte Zootécnico', 'Fim de Experimento',
 'Fim Experimento',
 'Encontrado Morto',
 'Velhos',
 'Erro de cadastro',
 'Canibalismo',
 'Fornecido Zoológico',
 'Para acasalamento',
 'UEL',
 'Animais Doentes',
 'Mudança',
 'Transferencia cx',
 'Cascavel',
 'Troca de Macho',
 'Monitoramento Sanitário',
 'Ivermectina',
 'Excesso de Filhotes',
 'Exp Lorena']
lista_retorno = list(map(lambda valor: TextBlob(valor).translate(from_lang='pt', to='en'), lista))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-65d9b84967cf> in <module>
#      17  'Excesso de Filhotes',
#      18  'Exp Lorena']
# ---> 19 lista_retorno = list(map(lambda valor: TextBlob(valor).translate(from_lang='pt', to='en'), lista))
#
# <ipython-input-50-65d9b84967cf> in <lambda>(valor)
#      17  'Excesso de Filhotes',
#      18  'Exp Lorena']
# ---> 19 lista_retorno = list(map(lambda valor: TextBlob(valor).translate(from_lang='pt', to='en'), lista))
#
# ~/anaconda3/lib/python3.7/site-packages/textblob/blob.py in translate(self, from_lang, to)
#     545         """
#     546         return self.__class__(self.translator.translate(self.raw,
# --> 547                               from_lang=from_lang, to_lang=to))
#     548
#     549     def detect_language(self):
#
# ...
