# %%
import matplotlib.pyplot

# %%
matplotlib.__version__
# Out:
# '3.3.0'

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3])


plt.title('Testando essa merda de fonte', fontname='Comic Sans MS')
plt.show()
